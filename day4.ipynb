# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitakanwar/day1.ipynb/blob/main/day4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("rakshita")
# Out:
# rakshita
