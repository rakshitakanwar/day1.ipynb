# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitakanwar/day1.ipynb/blob/main/day6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class student:
  name="ram"
  rollno=123

s=student()   #s=object
print(s.name)  #name=attribute
# Out:
# ram

# %%
class Student:
  def __init__(self,name,roll_no):
    self.name=name
    self.roll_no=roll_no
s=Student("ram",123)
print(s.name)
# Out:
# ram

# %%
class Student:
  def __init__(name,n,roll_no):
    name.n=n
    name.roll_no=roll_no
s=Student("ram",123)
print(s.n)
# Out:
# ram

# %%
class Student:
  def __init__(self,name,roll_no,age):
    self.name=name
    self.roll_no=roll_no
    self.age=age
s=Student("ram",15,21)
print(s.age,s.name)
print(s.roll_no)
# Out:
# 21 ram
# 15

# %%
class Student:
  def __init__(this,name,roll_no,age):
    this.name=name
    this.age=age
    this.roll_no=roll_no

s=Student(name='ram',roll_no=123,age=22)
print(s.name,s.age,s.roll_no)
# Out:
# ram 22 123

# %%
class Student:
  def __init__(this,name='dd',roll_no=122,age=None):
    this.name=name
    this.roll_no=roll_no
    this.age=age

s=Student('ram',123)
print(s.name,s.age,s.roll_no)

s1=Student('raj',111,44)
print(s1.name,s1.roll_no,s1.age)

s2=Student()
print(s2.name,s2.age,s2.roll_no)
# Out:
# ram None 123
# raj 111 44
# dd None 122

# %%
class Student:
  def __init__(this,*argspp):
    # print(type(args))  (args=tuple=> immutable)
    # print(args)  (tupple format)
    this.vv=argspp

s=Student('ram',123,20)
print(s.vv[0],s.vv[1],s.vv[2],)
# Out:
# ram 123 20

# %%
class Student:
  def __init__(self,*args):
    self.data=args

s=Student(['ram','raj','arya'])
print(s.data[0][0],)
# Out:
# ram

# %%
class Student:
  def __init__(self,*args):
    self.data=args

s=Student({'user':['sakshi',"rakshita","neha","sneha"]},{'add.':{"home":'civl_lines','office':'japur'}})
print(s.data[0]['user'])
print(s.data[1]['add.']['home'])
print(s.data[1]['add.']['office'])
# Out:
# ['sakshi', 'rakshita', 'neha', 'sneha']
# civl_lines
# japur

# %%
class Student:
  def __init__(self,name,rollno):
    self.name=name
    self.rollno=rollno

  def getName(self):
     print(self.name)


  def updateName(self):
    self.name='hello'
    print(self.name)

  def deleteName(self):
    del self.name
    print(self.name)

  def createName(self):
    self.full_name="ram"
    print(self.full_name)

s=Student('RAJ',123)
s.createName()
# Out:
# ram

# %%
class Student:
  def __init__(self,name,roll_no):
    print("auto start")
    self.name = name
    self.roll_no = roll_no
  # get
  def updateName(self,name=None): # default value -> none
    if name != None:
      self.name = name
    print(self.name)


inst = Student("Sakshi",123)
inst.updateName("rajendra")

inst1 = Student("Ram",321)
inst1.updateName()
# Out:
# auto start
# rajendra
# auto start
# Ram

# %%
# inheritance
class Student:
  def __init__(self, name,rollno):
    self.name=name
    self.rollno=rollno
  def getdata(self):
    print(self.name,self.rollno)

s=Student('RAM',123)
s.getdata()

class Address(Student):
  def __init__(self,name,rollno,city,state):
    self.city=city
    self.state=state

    super().__init__(name,rollno)
    # extra wreitten
    # self.name=name
    # self.rollno=rollno

  def getAddress(self):
    print(self.city,self.state)

a=Address('RAM',123,'JAIPUR','RAJASTHAN')
a.getAddress()
a.getdata()
# Out:
# RAM 123
# JAIPUR RAJASTHAN
# RAM 123
