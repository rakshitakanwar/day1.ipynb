# %% [markdown]
# <a href="https://colab.research.google.com/github/rakshitakanwar/day1.ipynb/blob/main/day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Rakshita")
# Out:
# Rakshita

# %% [markdown]
# #Operators
# 1. arithmetic=> +,-,/,*
# 2. relational=> >=,<=,>,<,==
# 3. assignment=> +=,-=,*=,%=
# 4. logical=> and ,or, not
# 5. bitwise=> &, |

# %%
#arithmetic
num1=20
num2=60
print(num1+num2)
# Out:
# 80

# %%
num1=90
num2=70
print(num1-num2)
print(num1*num2)
print(num1/num2)
# Out:
# 20
# 6300
# 1.2857142857142858

# %%
num1=100
num2=7
print(num1//num2)
print(num1%num2)
# Out:
# 14
# 2

# %%
num1=5
num2=2
print(num1**num2)
# Out:
# 25

# %%
#relational
num1=10
num2=20
print(num1>num2)
print(num1<num2)
# Out:
# False
# True

# %%
num1=10
num2=10
print(num1>=num2)
# Out:
# True

# %%
num1=90
num2=70
print(num1==num2)
print(num1!=num2)
# Out:
# False
# True

# %%
#assignment
num1=10
num2=20
num1+=num2
print(num1)
# Out:
# 30

# %%
num1=90
num2=20
num1-=num2
print(num1)
# Out:
# 70

# %%
num1=90
num2=20
num1*=num2
print(num1)
# Out:
# 1800

# %%
num1=90
num2=20
num1%=num2
print(num1)
# Out:
# 10

# %%
#logical
num1=10
num2=20
print(num1 and num2)
# Out:
# 20

# %%
name="hi"
number=3
print(name and number)
# Out:
# 3

# %%
num1=20
num2=90
print(num1 or num2)
# Out:
# 20

# %%
a=10
b=20
c=30
print(not(a<b and b>c or c>a))
# Out:
# False

# %%
a="hello"
b=10
c=[]
print(a and b and c)
# Out:
# []

# %%
#Bitwise operator
num1=5
num2=3
print(num1 & num2)
# Out:
# 1

# %%
num1=5
num2=3
print(num1 | num2)
# Out:
# 7
